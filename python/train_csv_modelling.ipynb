# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import (
    StandardScaler,
    OneHotEncoder,
    LabelEncoder,
    MinMaxScaler
)

import torch
from torch.utils.data import DataLoader

from utils import *
from model import *
from train import *

# %load_ext autoreload
# %autoreload 2

SEED = 42

device = torch.device(
    "cuda" if torch.cuda.is_available() else
    'mps' if torch.backends.mps.is_available() else
    "cpu"
)

# %% [markdown]
# # Using only `train.csv`

# %%
train_csv_path = "../../ucla-stats-101-c-2024-su-regression/train.csv"
train_csv = pd.read_csv(train_csv_path)

train_csv = train_csv.drop(['order_totals'], axis=1)
train_csv.columns
# Out:
# Index(['q_demos_state', 'year', 'month', 'log_total', 'count', 'count_female',
#        'count_male', 'count_less5', 'count_5to10', 'count_over10', 'count_hh1',
#        'count_hh2', 'count_hh3', 'count_hh4', 'count_howmany1',
#        'count_howmany2', 'count_howmany3', 'count_howmany4', 'count_1824',
#        'count_2534', 'count_3544', 'count_4554', 'count_5564', 'count_65up',
#        'count_und25k', 'count_2549k', 'count_5074k', 'count_7599k',
#        'count_100149k', 'count_150kup', 'count_lessHS', 'count_HS', 'count_B',
#        'count_G'],
#       dtype='object')

# %%
_X = train_csv.drop('log_total', axis=1)
_y = train_csv.log_total.to_numpy()

# initial split
_X, _X_test, y, y_test = train_test_split(
    _X, _y, test_size=0.2, stratify=_X.q_demos_state, random_state=SEED
)

# train set and eval set
_X_train, _X_eval, y_train, y_eval = train_test_split(
    _X, y, test_size=0.1, stratify=_X.q_demos_state, random_state=SEED
)

print('Feature Shapes:')
print(f'\traw train: {_X_train.shape}')
print(f'\traw eval: {_X_eval.shape}')
print(f'\traw test: {_X_test.shape}')
# Out:
# Feature Shapes:
# 	raw train: (2117, 33)
# 	raw eval: (236, 33)
# 	raw test: (589, 33)

# %%
categorical_columns = [
    'q_demos_state',
    'year',
    'month'
]

one_hot_enc = OneHotEncoder()

categorical_pipeline = Pipeline(
    [
        ('encoder', one_hot_enc)
    ]
)

numerical_columns = [
    'count', 'count_female', 'count_male', 
    'count_less5', 'count_5to10', 'count_over10', 
    'count_hh1', 'count_hh2', 'count_hh3', 'count_hh4', 
    'count_howmany1', 'count_howmany2', 'count_howmany3', 'count_howmany4',
    'count_1824', 'count_2534', 'count_3544', 'count_4554', 'count_5564', 'count_65up',
    'count_und25k', 'count_2549k', 'count_5074k', 'count_7599k', 'count_100149k', 'count_150kup', 
    'count_lessHS', 'count_HS', 'count_B', 'count_G'
]

scaler = StandardScaler()

numerical_pipeline = Pipeline(
    [
        ('std_scaler', scaler)
    ]
)

pipeline = ColumnTransformer(
    [
        ('numerical', numerical_pipeline, numerical_columns),
        ('categorical', categorical_pipeline, categorical_columns)
    ]
)

pipeline.fit(_X_train)

# train[numerical_columns].hist(
#     bins=100, figsize=(20, 15)
# )
# plt.show()
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(steps=[('std_scaler',
#                                                   StandardScaler())]),
#                                  ['count', 'count_female', 'count_male',
#                                   'count_less5', 'count_5to10', 'count_over10',
#                                   'count_hh1', 'count_hh2', 'count_hh3',
#                                   'count_hh4', 'count_howmany1',
#                                   'count_howmany2', 'count_howmany3',
#                                   'count_howmany4', 'count_1824', 'count_2534',
#                                   'count_3544', 'count_4554', 'count_5564',
#                                   'count_65up', 'count_und25k', 'count_2549k',
#                                   'count_5074k', 'count_7599k', 'count_100149k',
#                                   'count_150kup', 'count_lessHS', 'count_HS',
#                                   'count_B', 'count_G']),
#                                 ('categorical',
#                                  Pipeline(steps=[('encoder', OneHotEncoder())]),
#                                  ['q_demos_state', 'year', 'month'])])

# %%
X_train = pipeline.transform(_X_train)
X_eval = pipeline.transform(_X_eval)
X_test = pipeline.transform(_X_test)

print('Transformed Feature Shapes:')
print(f'\ttrain: {X_train.shape}')
print(f'\teval: {X_eval.shape}')
print(f'\ttest: {X_test.shape}')
# Out:
# Transformed Feature Shapes:
# 	train: (2117, 98)
# 	eval: (236, 98)
# 	test: (589, 98)

# %%
# configs
BATCH_SIZE = 32
LR = 1e-4
EPOCHS = 100

# %%
train_dataset = CustomDataset(X_train, y_train)
eval_dataset = CustomDataset(X_eval, y_eval)

train_dataloader = DataLoader(
    train_dataset, batch_size=BATCH_SIZE
)
eval_dataloader = DataLoader(
    eval_dataset, batch_size=BATCH_SIZE
)

# %%
input_size = X_train.shape[1]
hidden_1_size = 60
hidden_2_size = 7 + 2 # num categorical + num numeric
input_dropout = 0.1
hidden_dropout = 0.5

model_1 = ThreeLayerNet(
    input_size, 
    hidden_1_size, 
    hidden_2_size, 
    input_dropout,
    hidden_dropout
)

model_1
# Out:
# ThreeLayerNet(
#   (input_dropout): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=98, out_features=60, bias=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=60, out_features=9, bias=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc3): Linear(in_features=9, out_features=1, bias=True)
# )

# %%
train_losses, eval_losses = solver(
    model_1, 
    train_dataloader, 
    eval_dataloader,
    LR,
    EPOCHS,
    True,
    100
)
# Out:
# Training ThreeLayerNet on mps...
# Epoch: 1/100, Step: 1/67, Validation Loss: 9.92822
# Epoch: 2/100, Step: 1/67, Validation Loss: 9.29636
# Epoch: 3/100, Step: 1/67, Validation Loss: 8.59097
# Epoch: 4/100, Step: 1/67, Validation Loss: 7.36471
# Epoch: 5/100, Step: 1/67, Validation Loss: 6.74825
# Epoch: 6/100, Step: 1/67, Validation Loss: 4.38642
# Epoch: 7/100, Step: 1/67, Validation Loss: 7.18181
# Epoch: 8/100, Step: 1/67, Validation Loss: 4.69077
# Epoch: 9/100, Step: 1/67, Validation Loss: 5.25376
# Epoch: 10/100, Step: 1/67, Validation Loss: 4.13685
# Epoch: 11/100, Step: 1/67, Validation Loss: 4.36089
# Epoch: 12/100, Step: 1/67, Validation Loss: 4.69684
# Epoch: 13/100, Step: 1/67, Validation Loss: 4.51704
# Epoch: 14/100, Step: 1/67, Validation Loss: 6.53942
# Epoch: 15/100, Step: 1/67, Validation Loss: 4.72749
# Epoch: 16/100, Step: 1/67, Validation Loss: 3.67082
# Epoch: 17/100, Step: 1/67, Validation Loss: 4.82076
# Epoch: 18/100, Step: 1/67, Validation Loss: 3.15789
# Epoch: 19/100, Step: 1/67, Validation Loss: 2.08457
# Epoch: 20/100, Step: 1/67, Validation Loss: 3.82190
# Epoch: 21/100, Step: 1/67, Validation Loss: 4.60247
# Epoch: 22/100, Step: 1/67, Validation Loss: 2.99015
# Epoch: 23/100, Step: 1/67, Validation Loss: 2.70323
# Epoch: 24/100, Step: 1/67, Validation Loss: 4.68706
# Epoch: 25/100, Step: 1/67, Validation Loss: 3.32873
# Epoch: 26/100, Step: 1/67, Validation Loss: 2.72827
# Epoch: 27/100, Step: 1/67, Validation Loss: 2.58786
# Epoch: 28/100, Step: 1/67, Validation Loss: 2.47878
# Epoch: 29/100, Step: 1/67, Validation Loss: 2.55253
# Epoch: 30/100, Step: 1/67, Validation Loss: 3.46112
# Epoch: 31/100, Step: 1/67, Validation Loss: 3.66690
# Epoch: 32/100, Step: 1/67, Validation Loss: 2.83127
# Epoch: 33/100, Step: 1/67, Validation Loss: 1.81396
# Epoch: 34/100, Step: 1/67, Validation Loss: 2.56503
# Epoch: 35/100, Step: 1/67, Validation Loss: 2.41645
# Epoch: 36/100, Step: 1/67, Validation Loss: 1.96568
# Epoch: 37/100, Step: 1/67, Validation Loss: 3.38015
# Epoch: 38/100, Step: 1/67, Validation Loss: 2.42846
# Epoch: 39/100, Step: 1/67, Validation Loss: 3.83608
# Epoch: 40/100, Step: 1/67, Validation Loss: 3.03298
# Epoch: 41/100, Step: 1/67, Validation Loss: 2.86809
# Epoch: 42/100, Step: 1/67, Validation Loss: 2.34564
# Epoch: 43/100, Step: 1/67, Validation Loss: 2.76213
# Epoch: 44/100, Step: 1/67, Validation Loss: 3.76947
# Epoch: 45/100, Step: 1/67, Validation Loss: 2.42411
# Epoch: 46/100, Step: 1/67, Validation Loss: 2.61630
# Epoch: 47/100, Step: 1/67, Validation Loss: 4.53759
# Epoch: 48/100, Step: 1/67, Validation Loss: 4.47678
# Epoch: 49/100, Step: 1/67, Validation Loss: 3.97045
# Epoch: 50/100, Step: 1/67, Validation Loss: 2.44755
# Epoch: 51/100, Step: 1/67, Validation Loss: 2.30555
# Epoch: 52/100, Step: 1/67, Validation Loss: 1.90671
# Epoch: 53/100, Step: 1/67, Validation Loss: 2.12554
# Epoch: 54/100, Step: 1/67, Validation Loss: 3.38371
# Epoch: 55/100, Step: 1/67, Validation Loss: 2.14833
# Epoch: 56/100, Step: 1/67, Validation Loss: 2.24357
# Epoch: 57/100, Step: 1/67, Validation Loss: 4.56683
# Epoch: 58/100, Step: 1/67, Validation Loss: 3.79445
# Epoch: 59/100, Step: 1/67, Validation Loss: 2.94618
# Epoch: 60/100, Step: 1/67, Validation Loss: 2.88453
# Epoch: 61/100, Step: 1/67, Validation Loss: 2.60510
# Epoch: 62/100, Step: 1/67, Validation Loss: 2.80245
# Epoch: 63/100, Step: 1/67, Validation Loss: 3.58410
# Epoch: 64/100, Step: 1/67, Validation Loss: 2.31356
# Epoch: 65/100, Step: 1/67, Validation Loss: 2.13340
# Epoch: 66/100, Step: 1/67, Validation Loss: 2.60346
# Epoch: 67/100, Step: 1/67, Validation Loss: 2.54090
# Epoch: 68/100, Step: 1/67, Validation Loss: 2.66337
# Epoch: 69/100, Step: 1/67, Validation Loss: 3.70544
# Epoch: 70/100, Step: 1/67, Validation Loss: 2.71741
# Epoch: 71/100, Step: 1/67, Validation Loss: 3.63587
# Epoch: 72/100, Step: 1/67, Validation Loss: 1.58120
# Epoch: 73/100, Step: 1/67, Validation Loss: 2.36238
# Epoch: 74/100, Step: 1/67, Validation Loss: 3.15325
# Epoch: 75/100, Step: 1/67, Validation Loss: 1.87184
# Epoch: 76/100, Step: 1/67, Validation Loss: 2.23067
# Epoch: 77/100, Step: 1/67, Validation Loss: 1.74671
# Epoch: 78/100, Step: 1/67, Validation Loss: 2.33294
# Epoch: 79/100, Step: 1/67, Validation Loss: 3.71484
# Epoch: 80/100, Step: 1/67, Validation Loss: 1.95366
# Epoch: 81/100, Step: 1/67, Validation Loss: 1.89132
# Epoch: 82/100, Step: 1/67, Validation Loss: 2.89259
# Epoch: 83/100, Step: 1/67, Validation Loss: 2.32593
# Epoch: 84/100, Step: 1/67, Validation Loss: 3.14873
# Epoch: 85/100, Step: 1/67, Validation Loss: 1.89772
# Epoch: 86/100, Step: 1/67, Validation Loss: 1.79680
# Epoch: 87/100, Step: 1/67, Validation Loss: 2.40314
# Epoch: 88/100, Step: 1/67, Validation Loss: 2.73958
# Epoch: 89/100, Step: 1/67, Validation Loss: 3.18422
# Epoch: 90/100, Step: 1/67, Validation Loss: 2.45599
# Epoch: 91/100, Step: 1/67, Validation Loss: 2.19972
# Epoch: 92/100, Step: 1/67, Validation Loss: 2.49344
# Epoch: 93/100, Step: 1/67, Validation Loss: 2.69121
# Epoch: 94/100, Step: 1/67, Validation Loss: 3.31467
# Epoch: 95/100, Step: 1/67, Validation Loss: 3.27382
# Epoch: 96/100, Step: 1/67, Validation Loss: 3.06543
# Epoch: 97/100, Step: 1/67, Validation Loss: 1.25750
# Epoch: 98/100, Step: 1/67, Validation Loss: 2.23280
# Epoch: 99/100, Step: 1/67, Validation Loss: 2.85935
# Epoch: 100/100, Step: 1/67, Validation Loss: 3.89547

# %%
with torch.no_grad():
    model_1.cpu()
    preds = model_1(torch.from_numpy(X_test).to(torch.float32)).squeeze()

mse = nn.MSELoss()
mse(preds, torch.from_numpy(y_test).to(torch.float32)).item()
# Out:
# 0.022130941972136497

# %% [markdown]
# # Predict on `test.csv`

# %%
test_csv_path = "../../ucla-stats-101-c-2024-su-regression/test.csv"
test_csv = pd.read_csv(test_csv_path)

test_ids = test_csv.id
test_csv = test_csv.drop(['id'], axis=1)

_test = pipeline.transform(test_csv)

print('Transformed Test Feature Shapes:')
print(f'\ttrain: {_test.shape}')
# Out:
# Transformed Test Feature Shapes:
# 	train: (2952, 98)

# %%
with torch.no_grad():
    model_1.cpu()
    preds = model_1(torch.from_numpy(_test).to(torch.float32)).squeeze()

model_1_preds = pd.DataFrame(
    {"id": test_ids,
     "log_total": preds
    }
)

save_path = "../preds/preds_3LNN_train_andy_0726.csv"

model_1_preds.to_csv(
    save_path, index=False
)

model_1_preds
# Out:
#         id  log_total
# 0        1   3.186365
# 1        2   3.187080
# 2        3   3.247694
# 3        4   3.235007
# 4        5   3.226147
# ...    ...        ...
# 2947  2948   2.437182
# 2948  2949   2.504473
# 2949  2950   2.582794
# 2950  2951   2.646356
# 2951  2952   2.395306
#
# [2952 rows x 2 columns]
